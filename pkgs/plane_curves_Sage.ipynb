# %%
t = var('t')

# %%
def x(t):
    return t

def y(t):
    return t ** 2

def f(t):
    return vector([x(t),y(t)])

# %%
def l(a,b):
    return integral(norm(diff(f(t),t)), (t,a,b))

# %%
l(0,1).n()
# Out:
# 1.47894285754460

# %%
parametric_plot((f(t)), (t, 0, 1))
# Out:
# Graphics object consisting of 1 graphics primitive
